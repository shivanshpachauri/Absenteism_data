# %%
import pandas as pd
import numpy as np

# %%
no_age=pd.read_csv("Removedageandid.csv")

# %%
age_encoded=pd.read_csv("Age_encoded.csv")

# %%
concatenated=pd.concat([no_age,age_encoded],axis=1)

# %%
concatenated.head()
# Out:
#    Unnamed: 0  Reason for Absence        Date  Transportation Expense  \
# 0           0                  26  07/07/2015                     289
# 1           1                   0  14/07/2015                     118
# 2           2                  23  15/07/2015                     179
# 3           3                   7  16/07/2015                     279
# 4           4                  23  23/07/2015                     289
#
#    Distance to Work  Daily Work Load Average  Body Mass Index  Education  \
# 0                36                  239.554               30          1
# 1                13                  239.554               31          1
# 2                51                  239.554               31          1
# 3                 5                  239.554               24          1
# 4                36                  239.554               30          1
#
#    Children  Pets  ...     39     40     41     43     46     47     48  \
# ...

# %%
concatenated.to_csv("concatenateddata.csv")
